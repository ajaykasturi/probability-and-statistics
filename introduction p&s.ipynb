# %% [markdown]
# <a href="https://colab.research.google.com/github/ajaykasturi/probability-and-statistics/blob/main/introduction%20p%26s.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a="ajay"
print(a)
# Out:
# ajay
